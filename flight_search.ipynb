# %%
import json
import importlib
import flight_api
importlib.reload(flight_api)
from flight_api import search_multiple_origins

origins = origins = [
    "LIS", "CMN", "TUN", "CDG", "LON", "ZRH", "BRU", "AMS",
    "BER", "PRG", "WAW", "VIE", "LJU", "FCO", "BUD", "ZAG",
    "OTP", "SOF", "ATH", "IST", "MAD"]

results = search_multiple_origins(origins, "BCN", "2026-05-01")

for r in results:
    print("----", r["origin"], "----")
    if "error" in r:
        print("Error:", r["error"])
    else:
        print("直行便件数:", len(r["data"]["data"]))
# Out:
# ---- LIS ----
# 直行便件数: 15
# ---- CMN ----
# 直行便件数: 15
# ---- TUN ----
# 直行便件数: 15
# ---- CDG ----
# 直行便件数: 15
# ---- LON ----
# 直行便件数: 15
# ---- ZRH ----
# 直行便件数: 15
# ---- BRU ----
# 直行便件数: 15
# ---- AMS ----
# 直行便件数: 15
# ---- BER ----
# 直行便件数: 15
# ---- PRG ----
# 直行便件数: 15
# ---- WAW ----
# 直行便件数: 15
# ---- VIE ----
# 直行便件数: 15
# ---- LJU ----
# 直行便件数: 15
# ---- FCO ----
# 直行便件数: 15
# ---- BUD ----
# 直行便件数: 15
# ---- ZAG ----
# 直行便件数: 15
# ---- OTP ----
# 直行便件数: 15
# ---- SOF ----
# 直行便件数: 15
# ---- ATH ----
# 直行便件数: 15
# ---- IST ----
# 直行便件数: 15
# ---- MAD ----
# 直行便件数: 15
