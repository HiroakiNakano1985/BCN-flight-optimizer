# %%
from flight_api import search_multiple_origins
import json

origins = ["LON", "PAR", "BER", "MAD", "ROM"]

results = search_multiple_origins(origins, "BCN", "2026-05-01")

for r in results:
    print("----", r["origin"], "----")
    if "error" in r:
        print("Error:", r["error"])
    else:
        print("直行便件数:", len(r["data"]["data"]))
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from flight_api import search_multiple_origins
#       2 import json
#       4 origins = ["LON", "PAR", "BER", "MAD", "ROM"]
#
# ImportError: cannot import name 'search_multiple_origins' from 'flight_api' (c:\python\prototyping\BCN-flight-optimizer\flight_api.py)
